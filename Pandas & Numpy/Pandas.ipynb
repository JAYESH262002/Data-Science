# %% [markdown]
# ### <center><div class='alert alert-info'>Pandas</div></center>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# `df.isnull().sum()`

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.describe(exclude='number')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# Will show index which is of `object` types

# %%
lst = [1,2,3,4,5,6,7,8,9,'Jayesh Raghuvanshi','Raj Raghuvanshi']

# %%
lst[0]
# Out:
# 1

# %%
lst[lst==4]
# Out:
# 1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Embarked'] == 'S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
df['Name'].head(15)
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df['Name'][0:15:1]  # [start:end:step]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df[df['Age'].isnull() ==True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#if there are 800 non NAN-value then the column will get dropped
df.dropna(axis=1, thresh= 800)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
age = df[df['Age'].isnull() ==True].index
age
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
df[df.index == 5]
# Out:
#    PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 5            6         0       3  Moran, Mr. James  male  NaN      0      0
#
#    Ticket    Fare Cabin Embarked
# 5  330877  8.4583   NaN        Q

# %% [markdown]
# This is row wise selection

# %%
df.loc[age]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# it will filter data wich don't have age

# %%
df[df['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df.groupby('Name')['Fare'].sum().sort_values(ascending=False)
# Out:
# Name
# Ward, Miss. Anna                      512.3292
# Cardeza, Mr. Thomas Drake Martinez    512.3292
# Lesurer, Mr. Gustave J                512.3292
# Fortune, Miss. Alice Elizabeth        263.0000
# Fortune, Miss. Mabel Helen            263.0000
#                                         ...
# Tornquist, Mr. William Henry            0.0000
# Parkes, Mr. Francis "Frank"             0.0000
# Parr, Mr. William Henry Marsh           0.0000
# Reuchlin, Jonkheer. John George         0.0000
# Knight, Mr. Robert J                    0.0000
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# ### <div class='alert alert-info'>Question</div>

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# #### <div class='alert alert-info'>Find how many male and female passenger was onboarded</div>

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [raw]
# How many survived we have.

# %% [markdown]
# #### <div class='alert alert-info'>Find how many male and female passenger was onboarded</div>

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %% [raw]
# How many casuality we have.

# %% [markdown]
# #### <div class='alert alert-info'>Find how many male and female passenger was onboarded</div>

# %%
len(df[df['Survived'] == 0])
# Out:
# 549

# %% [raw]
# what is name of the person who is the eldest one.

# %% [markdown]
# #### <div class='alert alert-info'>Find how many male and female passenger was onboarded</div>

# %%
df[df['Age'] == max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [raw]
# How many passenger do we have in first class, second and third class.

# %% [markdown]
# #### <div class='alert alert-info'>Find how many male and female passenger was onboarded</div>

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass')['Pclass'].value_counts()
# Out:
# Pclass  Pclass
# 1       1         216
# 2       2         184
# 3       3         491
# Name: Pclass, dtype: int64

# %% [markdown]
# #### <div class='alert alert-info'>How many person we have whose name start with 's'.</div>

# %%
count = 0
for i in df['Name']:
    if i.startswith('S'):
        count+=1
print(count)
# Out:
# 86

# %%
df[df['Name'].str.startswith('S')].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 12           13         0       3
# 23           24         1       1
# 31           32         1       1
# 48           49         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 10                 Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                  Saundercock, Mr. William Henry    male  20.0      0
# 23                    Sloper, Mr. William Thompson    male  28.0      0
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 48                             Samaan, Mr. Youssef    male   NaN      2
#
#     Parch     Ticket      Fare Cabin Embarked
# 10      1    PP 9549   16.7000    G6        S
# 12      0  A/5. 2151    8.0500   NaN        S
# 23      0     113788   35.5000    A6        S
# 31      0   PC 17569  146.5208   B78        C
# 48      0       2662   21.6792   NaN        C

# %%
len(df[df['Name'].str.startswith('S')])
# Out:
# 86

# %% [markdown]
# #### <div class='alert alert-info'>Try create a new column which is a summatition of 'SibSp' and 'Parch'.</div>

# %%
df['Sum'] = df['SibSp'] + df['Parch']
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 329          330         1       1
# 366          367         1       1
# 333          334         0       3
# 741          742         0       1
# 62            63         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 329                      Hippach, Miss. Jean Gertrude  female  16.0      0
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 333                   Vander Planke, Mr. Leo Edmondus    male  16.0      2
# 741                     Cavendish, Mr. Tyrell William    male  36.0      1
# 62                        Harris, Mr. Henry Birkhardt    male  45.0      1
#
#      Parch  Ticket     Fare Cabin Embarked  Sum
# 329      1  111361  57.9792   B18        C    1
# 366      0  110813  75.2500   D37        C    1
# 333      0  345764  18.0000   NaN        S    2
# 741      0   19877  78.8500   C46        S    1
# 62       0   36973  83.4750   C83        S    1

# %% [markdown]
# #### <div class='alert alert-info'>How many person do we have below age of 25.</div>

# %%
len(df[df['Age']<25])
# Out:
# 278

# %% [markdown]
# #### <div class='alert alert-info'>How many person dies whose age was less than 40.</div>

# %%
len(df[(df['Survived'] == 0) & (df['Age'] < 40)])
# Out:
# 322

# %% [markdown]
# #### <div class='alert alert-info'>From a cabin column seperate text and numeric value.</div>

# %%
import re

replace = re.compile("([a-zA-Z]+)")

df['string_cabin_list'] = df['Cabin'].str.extract(replace)
df['number_cabin_list'] = df['Cabin'].str.replace(replace,"")

# %%
df['string_cabin_list']
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: string_cabin_list, Length: 891, dtype: object

# %%
df['number_cabin_list']
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: number_cabin_list, Length: 891, dtype: object

# %%
df2 = pd.read_csv('CSV/bank.csv', sep=';')
df2.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# `sep=';'` because it is seperated with ';'

# %% [raw]
# 1.How many campaign available in this dataset.
# 2.How many users do we have with housing and personal loan.
# 3.How many person do we have whose age is 60+.
# 4.In which month we have targeted most of the customer.
# 5.Which mode of call is giving you more result.
# 6.How many enterpreneur do we have in this list.
# 7.How many customer do we have with negative balance.
# 7.Prepare a group of data based on education level.

# %%
df2.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [raw]
# 1.How many campaign available in this dataset.

# %% [raw]
# 5.Which mode of call is giving you more result.

# %%
df3 = df2.groupby(['contact', 'y']).count()
df3
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
# ...

# %%
df3.loc['cellular']
# Out:
#       age   job  marital  education  default  balance  housing  loan   day  \
# y
# no   2480  2480     2480       2480     2480     2480     2480  2480  2480
# yes   416   416      416        416      416      416      416   416   416
#
#      month  duration  campaign  pdays  previous  poutcome
# y
# no    2480      2480      2480   2480      2480      2480
# yes    416       416       416    416       416       416

# %%
df3.loc['cellular', 'yes']
# Out:
# age          416
# job          416
# marital      416
# education    416
# default      416
# balance      416
# housing      416
# loan         416
# day          416
# month        416
# duration     416
# campaign     416
# pdays        416
# previous     416
# poutcome     416
# Name: (cellular, yes), dtype: int64

# %%
df3.loc['cellular', 'yes'][0]
# Out:
# 416

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ...  Fare              Sum            \
#             max  count      mean  ...   75%       max  count      mean
# Survived                          ...
# 0         891.0  549.0  2.531876  ...  26.0  263.0000  549.0  0.883424
# 1         890.0  342.0  1.950292  ...  57.0  512.3292  342.0  0.938596
#
#
#                std  min  25%  50%  75%   max
# Survived
# 0         1.830669  0.0  0.0  0.0  1.0  10.0
# 1         1.186076  0.0  0.0  1.0  2.0   6.0
#
# [2 rows x 56 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %% [markdown]
# **`axis=0 -> row`**
# **`axis=1 -> column`**

# %% [markdown]
# **`pd.concat([df1,df2])`** <br>
# **`pd.concat([df1,df2], axis=1)`** #to concatinate column wise

# %% [markdown]
# **`pd.merge(df1,df2,on='age')`**<br>
# All values of age which are same for both df1 and df2 will be displayed<br>

# %% [markdown]
# - how='inner' is like intersection in sets
# - how='left' all left plus intersextion
# - how='right' all right plus intersection
# - how='outer' means select all

# %% [markdown]
# **`df2.set_index('age')`**  <font color='green'> New Function </font>

# %% [markdown]
# **`df2.rename(columns=['column1': 'column2', 'coumn3':'column4']`** <br>
# **`df2.join(df3)` will not work for same column name**

# %% [markdown]
# ### <div class='alert alert-info'>DataFrame</div>

# %%
df=pd.DataFrame({'col1':[1,2,3],
               'col2':[6,7,8],
               'col3':"Jayesh Singh Raghuvanshi"})
df
# Out:
#    col1  col2                      col3
# 0     1     6  Jayesh Singh Raghuvanshi
# 1     2     7  Jayesh Singh Raghuvanshi
# 2     3     8  Jayesh Singh Raghuvanshi

# %%
df=pd.DataFrame({'col1':[1,2,3],
               'col2':[6,7,8],
               'col3':"Jayesh Singh Raghuvanshi".split()})
df
# Out:
#    col1  col2         col3
# 0     1     6       Jayesh
# 1     2     7        Singh
# 2     3     8  Raghuvanshi

# %%
df['Sqr'] = df['col1']**2
df
# Out:
#    col1  col2         col3  Sqr
# 0     1     6       Jayesh    1
# 1     2     7        Singh    4
# 2     3     8  Raghuvanshi    9

# %%
df['col5'] = df['col3'].str[0]
df
# Out:
#    col1  col2         col3  Sqr col5
# 0     1     6       Jayesh    1    J
# 1     2     7        Singh    4    S
# 2     3     8  Raghuvanshi    9    R

# %%
lst = []
for i in df['col3']:
    lst.append(i[0])
df['col6'] = lst

# %%
df
# Out:
#    col1  col2         col3  Sqr col5 col6
# 0     1     6       Jayesh    1    J    J
# 1     2     7        Singh    4    S    S
# 2     3     8  Raghuvanshi    9    R    R

# %%
lst2=[]
for i in df['col5']:
    if(i=='J'):
        lst2.append('J')
    else:
        lst2.append('Z')
df['col6']=lst2

# %%
df
# Out:
#    col1  col2         col3  Sqr col5 col6
# 0     1     6       Jayesh    1    J    J
# 1     2     7        Singh    4    S    Z
# 2     3     8  Raghuvanshi    9    R    Z

# %%
def test(a):
    if a=='J':
        return 'J'
    else:
        return 'R'

# %%
del df['col6']

# %%
df['col7'] = df['col5'].apply(test)

# %%
df
# Out:
#    col1  col2         col3  Sqr col5 col7
# 0     1     6       Jayesh    1    J    J
# 1     2     7        Singh    4    S    R
# 2     3     8  Raghuvanshi    9    R    R

# %%
del df['col5']
df
# Out:
#    col1  col2         col3  Sqr col7
# 0     1     6       Jayesh    1    J
# 1     2     7        Singh    4    R
# 2     3     8  Raghuvanshi    9    R

# %%
df['col7_2'] = df['col7'].apply(lambda x: 'J' if x=='J' else 'R')

# %%
df
# Out:
#    col1  col2         col3  Sqr col7 col7_2
# 0     1     6       Jayesh    1    J      J
# 1     2     7        Singh    4    R      R
# 2     3     8  Raghuvanshi    9    R      R

# %%
del df['col7']
df
# Out:
#    col1  col2         col3  Sqr col7_2
# 0     1     6       Jayesh    1      J
# 1     2     7        Singh    4      R
# 2     3     8  Raghuvanshi    9      R

# %%
df['col8'] = df['col3'].apply(lambda x: len(x))

# %%
df
# Out:
#    col1  col2         col3  Sqr col7_2  col8
# 0     1     6       Jayesh    1      J     6
# 1     2     7        Singh    4      R     5
# 2     3     8  Raghuvanshi    9      R    11

# %%
import math
df['col9'] = df['Sqr'].apply(math.log)

# %%
df
# Out:
#    col1  col2         col3  Sqr col7_2  col8      col9
# 0     1     6       Jayesh    1      J     6  0.000000
# 1     2     7        Singh    4      R     5  1.386294
# 2     3     8  Raghuvanshi    9      R    11  2.197225
