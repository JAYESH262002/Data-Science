# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("heart.csv")
df.head(3)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0

# %% [markdown]
# ## sns.displot(df["Columns"]);

# %%
sns.displot(df["Age"]);

# %% [markdown]
# ## sns.displot(df["Columns"], kde=True)
# - ### kde=True -> will show a live onto the graph
# - ### color="colour-name"

# %%
sns.displot(df["Age"], kde=True, color="purple");

# %% [markdown]
# ## sns.distplot(df=["Columns"],hist=True)

# %%
sns.distplot(df["Age"], hist=True);
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["RestingBP"], kde=True, color="blue");
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["Cholesterol"]);
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %% [markdown]
# ## <font color="purple"> Pie-chart for categorical </font>

# %%
df.groupby("ChestPainType")["Cholesterol"].plot(kind="pie", autopct="0.1f");

# %% [markdown]
# ## Something really amazing happened

# %%
df.groupby("Sex").size().plot(kind="pie");

# %% [markdown]
# .size() -> counting the number of Male and Female present in data

# %%
df.groupby("RestingECG").size().plot(kind="pie");

# %%
df.groupby("HeartDisease").size().plot(kind="pie");

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %% [markdown]
# ## <font color="purple"> sns.violinplot()  </font>
# - ### sns.violinplot(x=df["column"], y=df["column2"])

# %%
sns.violinplot(y= df["HeartDisease"],x= df["Sex"]);

# %%
sns.violinplot(x=df["ExerciseAngina"], y=df["HeartDisease"]);

# %%
sns.violinplot(x=df["HeartDisease"], y=df["Age"]);

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %% [markdown]
# ## <font color="purple"> sns.heatmap(df.function()) </font>

# %% [markdown]
# - ### df.corr()

# %%
df.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %% [markdown]
# - ### sns.heatmap(df.corr())

# %%
sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# - ## sns.pairplot(df)
# ### <font color="purple"> It will plot the data of the heatmap ( correlation of every column with each other) </font>

# %%
sns.pairplot(df);

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %% [markdown]
# - ## sns.jointplot(df["column1], df["column2"])
#
#  ### <font color="purple"> It will show the correlation between two column </font>

# %%
sns.jointplot(x=df["Age"],y= df["Cholesterol"], kind="reg");

# %% [markdown]
# ### kind="ref" -> will show correlation in form of a line

# %%
sns.jointplot(x= 'Age', y='RestingBP', data=df, kind='reg');

# %% [markdown]
# ### same as ` sns.jointplot(df['Age'], df['RestingBP'])`

# %%
sns.jointplot(x='Age', y='RestingBP', data=df, kind='hex');
